# %%
# %pylab inline

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd

# %%
# Example: load a DSS dataset as a Pandas dataframe
mydataset = dataiku.Dataset("mydataset")
mydataset_df = mydataset.get_dataframe()

# %%
import os
import pandas as pd
import dataiku
from PIL import Image
import pytesseract
import re

class ImageTextExtractor:
    """
    A class to extract text from images stored in a Dataiku managed folder
    and write the results to a Dataiku dataset using a DataFrame.
    Only images with extracted text containing more than 5 words are included.
    """
    
    def __init__(self, input_folder_name, output_dataset_name):
        """
        Initialize the extractor with input folder and output dataset names.
        
        Args:
            input_folder_name: Name of the Dataiku managed folder containing images
            output_dataset_name: Name of the Dataiku dataset to write results to
        """
        self.input_folder = dataiku.Folder(input_folder_name)
        self.output_dataset = dataiku.Dataset(output_dataset_name)
        
    def extract_text_from_image(self, image_path):
        """
        Extract text from a single image using pytesseract OCR.
        
        Args:
            image_path: Path to the image file
            
        Returns:
            Extracted text as string with cleaned whitespace
        """
        try:
            image = Image.open(image_path)
            text = pytesseract.image_to_string(image)
            
            # Clean up the extracted text
            # Replace multiple whitespaces with a single space
            cleaned_text = re.sub(r'\s+', ' ', text)
            # Remove leading and trailing whitespace
            cleaned_text = cleaned_text.strip()
            
            return cleaned_text
        except Exception as e:
            print(f"Error extracting text from {image_path}: {str(e)}")
            return ""
    
    def process_all_images(self):
        """
        Process all images in the input folder and create a DataFrame with the results.
        Only include images with more than 5 words in the extracted text.
        Then write the DataFrame to the output dataset.
        """
        # Get list of files in the managed folder
        file_list = self.input_folder.list_paths_in_partition()
        
        # Prepare data for DataFrame
        image_names = []
        extracted_texts = []
        
        # Track statistics
        total_images = 0
        included_images = 0
        
        # Process each image file
        for file_path in file_list:
            if file_path.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.gif')):
                total_images += 1
                # Get the image name from the path
                image_name = os.path.basename(file_path)
                
                # Get the full path for the file in the managed folder
                with self.input_folder.get_download_stream(file_path) as stream:
                    # Save temporarily
                    temp_path = f"/tmp/{image_name}"
                    with open(temp_path, 'wb') as f:
                        f.write(stream.read())
                    
                    # Extract text
                    extracted_text = self.extract_text_from_image(temp_path)
                    
                    # Clean up
                    os.remove(temp_path)
                
                # Check if extracted text has more than 5 words
                word_count = len(extracted_text.split())
                if word_count > 5:
                    # Append to lists
                    image_names.append(image_name)
                    extracted_texts.append(extracted_text)
                    included_images += 1
                    print(f"Processed {image_name} - {word_count} words - INCLUDED")
                else:
                    print(f"Processed {image_name} - {word_count} words - SKIPPED (less than 5 words)")
        
        # Create DataFrame
        results_df = pd.DataFrame({
            "image_name": image_names,
            "extracted_text": extracted_texts,
            "word_count": [len(text.split()) for text in extracted_texts]
        })
        
        # Write DataFrame to output dataset
        self.output_dataset.write_with_schema(results_df)
        
        print(f"Total images processed: {total_images}")
        print(f"Images included in dataset: {included_images}")
        print(f"Images excluded (less than 5 words): {total_images - included_images}")
        
        return results_df

# Example usage:
def main():
    # Replace with your actual folder and dataset names
    extractor = ImageTextExtractor(
        input_folder_name="input_images_extracted_custom",
        output_dataset_name="images_data_extracted"
    )
    
    df = extractor.process_all_images()
    print(f"Text extraction completed! Added {len(df)} images to dataset.")

if __name__ == "__main__":
    main()
# Out:
# Processed HCP Affordability Bridge Eligible Letter_B2H_image1.jpeg - 191 words - INCLUDED
# Processed HCP Affordability Bridge Eligible Letter_B2H_image2.png - 2 words - SKIPPED (less than 5 words)
# Processed HCP Affordability Bridge Eligible Letter_B2H_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed Phase 1 Requirements - PSIT Patient Journey AI Model_image1.jpeg - 101 words - INCLUDED
# Processed Phase 1 Requirements - PSIT Patient Journey AI Model_image2.png - 28 words - INCLUDED
# Processed Phase 1 Requirements - PSIT Patient Journey AI Model_image3.png - 50 words - INCLUDED
# Processed Phase 1 Requirements - PSIT Patient Journey AI Model_image4.png - 85 words - INCLUDED
# Processed Phase 1 Requirements - PSIT Patient Journey AI Model_image5.png - 48 words - INCLUDED
# Processed AMB RC Intro to ARS Email_page1_image1.png - 2451 words - INCLUDED
# Processed ARTS RC I Can't Reach You Email_page1_image1.png - 2138 words - INCLUDED
# Processed ARS RC Sorry I Missed You Email_page1_image1.png - 2273 words - INCLUDED
# Error extracting text from /tmp/ARS RC Intro to ARS Email (from ARS)_page1_image1.png: cannot identify image file '/tmp/ARS RC Intro to ARS Email (from ARS)_page1_image1.png'
# Processed ARS RC Intro to ARS Email (from ARS)_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed ARS RC Appointment Reminder Email_page1_image1.png - 2224 words - INCLUDED
# Error extracting text from /tmp/64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page1_image1.png: cannot identify image file '/tmp/64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page1_image1.png'
# Processed 64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/65J-1910403 HUMIRA Complete Symptom Tracker_page1_image1.png: cannot identify image file '/tmp/65J-1910403 HUMIRA Complete Symptom Tracker_page1_image1.png'
# Processed 65J-1910403 HUMIRA Complete Symptom Tracker_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed Bridge Workshop Deck_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed ARS RC Intro to ARS Email (from ARS)_page2_image1.png - 2463 words - INCLUDED
# Error extracting text from /tmp/Bridge Workshop Deck_page1_image2.png: cannot identify image file '/tmp/Bridge Workshop Deck_page1_image2.png'
# Processed Bridge Workshop Deck_page1_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image1.png: cannot identify image file '/tmp/64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image1.png'
# Processed 64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/65J-1910403 HUMIRA Complete Symptom Tracker_page3_image1.png: cannot identify image file '/tmp/65J-1910403 HUMIRA Complete Symptom Tracker_page3_image1.png'
# Processed 65J-1910403 HUMIRA Complete Symptom Tracker_page3_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Bridge Workshop Deck_page1_image3.png: cannot identify image file '/tmp/Bridge Workshop Deck_page1_image3.png'
# Processed Bridge Workshop Deck_page1_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image3.png - 1 words - SKIPPED (less than 5 words)
# Processed Bridge Workshop Deck_page2_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image2.png: cannot identify image file '/tmp/64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image2.png'
# Processed 64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image4.png: cannot identify image file '/tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image4.png'
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image4.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/FAS Task Actions - Process - FAS Process-from 12-20-23 workshop_page1_image1.png: cannot identify image file '/tmp/FAS Task Actions - Process - FAS Process-from 12-20-23 workshop_page1_image1.png'
# Processed FAS Task Actions - Process - FAS Process-from 12-20-23 workshop_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed Draft_PSIT_Patient_Journey_AI_Model_slide4_image8.png - 0 words - SKIPPED (less than 5 words)
# Processed Bridge Status field in iEngage-Quick Reference Guide_slide1_image30.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide1_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-01-21 Bridge Program Workshop_slide3_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide3_image4.png - 9 words - INCLUDED
# Error extracting text from /tmp/64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image3.png: cannot identify image file '/tmp/64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image3.png'
# Processed 64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed Bridge Workshop Deck_page2_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed Bridge Status field in iEngage-Quick Reference Guide_slide1_image31.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide2_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed Draft_PSIT_Patient_Journey_AI_Model_slide4_image11.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/HCP Bridge Eligible Letter_B1U_page1_image1.png: cannot identify image file '/tmp/HCP Bridge Eligible Letter_B1U_page1_image1.png'
# Processed HCP Bridge Eligible Letter_B1U_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed Bridge Status field in iEngage-Quick Reference Guide_slide1_image32.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Bridge Workshop Deck_page2_image3.png: cannot identify image file '/tmp/Bridge Workshop Deck_page2_image3.png'
# Processed Bridge Workshop Deck_page2_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide2_image8.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-01-21 Bridge Program Workshop_slide3_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide5_image3.png - 9 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide6_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/FAS Task Actions - Process - FAS Process-from 12-20-23 workshop_page1_image2.png: cannot identify image file '/tmp/FAS Task Actions - Process - FAS Process-from 12-20-23 workshop_page1_image2.png'
# Processed FAS Task Actions - Process - FAS Process-from 12-20-23 workshop_page1_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide2_image10.png - 0 words - SKIPPED (less than 5 words)
# Processed Draft_PSIT_Patient_Journey_AI_Model_slide4_image12.png - 1 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image4.png: cannot identify image file '/tmp/64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image4.png'
# Processed 64N-1921715 HUMIRA Complete Symptom Tracker PEDs_page3_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed Bridge Status field in iEngage-Quick Reference Guide_slide1_image33.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide4_image1.png - 14 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide6_image4.png - 9 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide7_image5.png - 9 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide7_image6.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-01-21 Bridge Program Workshop_slide7_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image5.png: cannot identify image file '/tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image5.png'
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image5.png - 0 words - SKIPPED (less than 5 words)
# Processed Bridge Status field in iEngage-Quick Reference Guide_slide1_image36.png - 0 words - SKIPPED (less than 5 words)
# Processed Draft_PSIT_Patient_Journey_AI_Model_slide14_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-01-21 Bridge Program Workshop_slide6_image29.png - 9 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide8_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed Bridge Status field in iEngage-Quick Reference Guide_slide1_image37.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-01-21 Bridge Program Workshop_slide8_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide10_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed RC Haven't Talked in a While Email - Peds_page1_image1.png - 2042 words - INCLUDED
# Processed RC Cover Email - Peds_page1_image1.png - 2206 words - INCLUDED
# Processed 2025-01-21 Bridge Program Workshop_slide8_image3.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image6.png: cannot identify image file '/tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image6.png'
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image6.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/HCP Bridge Eligible Letter_B1U_page1_image2.png: cannot identify image file '/tmp/HCP Bridge Eligible Letter_B1U_page1_image2.png'
# Processed HCP Bridge Eligible Letter_B1U_page1_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide11_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-01-21 Bridge Program Workshop_slide8_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed RC Haven't Talked In A While Email_page1_image1.png - 2264 words - INCLUDED
# Error extracting text from /tmp/Bridge Workshop Deck_page2_image4.png: cannot identify image file '/tmp/Bridge Workshop Deck_page2_image4.png'
# Processed Bridge Workshop Deck_page2_image4.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Bridge Workshop Deck_page2_image5.png: cannot identify image file '/tmp/Bridge Workshop Deck_page2_image5.png'
# Processed Bridge Workshop Deck_page2_image5.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-01-21 Bridge Program Workshop_slide9_image2.png - 100 words - INCLUDED
# Processed 2025-01-21 Bridge Program Workshop_slide10_image2.png - 1 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide16_image3.png - 137 words - INCLUDED
# Processed RC I Can't Reach You Email_page1_image1.png - 2447 words - INCLUDED
# Processed Bridge Workshop Deck_page3_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/HCP Bridge Eligible Letter_B1U_page2_image1.png: cannot identify image file '/tmp/HCP Bridge Eligible Letter_B1U_page2_image1.png'
# Processed HCP Bridge Eligible Letter_B1U_page2_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Bridge Workshop Deck_page3_image2.png: cannot identify image file '/tmp/Bridge Workshop Deck_page3_image2.png'
# Processed Bridge Workshop Deck_page3_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide16_image4.png - 22 words - INCLUDED
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image1.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image1.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-01-21 Bridge Program Workshop_slide14_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed RC Insurance Email - Peds_page1_image1.png - 2177 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide17_image4.png - 26 words - INCLUDED
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide6_image4.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/HCP Bridge Eligible Letter_B1U_page2_image2.png: cannot identify image file '/tmp/HCP Bridge Eligible Letter_B1U_page2_image2.png'
# Processed HCP Bridge Eligible Letter_B1U_page2_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/HCP Bridge Eligible Letter_B1U_page3_image1.png: cannot identify image file '/tmp/HCP Bridge Eligible Letter_B1U_page3_image1.png'
# Processed HCP Bridge Eligible Letter_B1U_page3_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/HCP Bridge Eligible Letter_B1U_page3_image2.png: cannot identify image file '/tmp/HCP Bridge Eligible Letter_B1U_page3_image2.png'
# Processed HCP Bridge Eligible Letter_B1U_page3_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide8_image3.png - 1 words - SKIPPED (less than 5 words)
# Processed RC myAbbVie Assist Interim Assistance Email_page1_image1.png - 2296 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide17_image5.png - 10 words - INCLUDED
# Processed 2025-02-APS OS RIN AD_slide2_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed Examples of Complete App Push Notifications and Pop-ups_slide3_image2.png - 293 words - INCLUDED
# Processed Examples of Complete App Push Notifications and Pop-ups_slide5_image2.png - 5 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide18_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed Bridge Workshop Deck_page3_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-APS OS RIN AD_slide3_image13.png - 0 words - SKIPPED (less than 5 words)
# Processed RC Welcome Email_page1_image1.png - 2422 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide18_image5.png - 3 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Bridge Workshop Deck_page3_image4.png: cannot identify image file '/tmp/Bridge Workshop Deck_page3_image4.png'
# Processed Bridge Workshop Deck_page3_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide10_image6.png - 7 words - INCLUDED
# Error extracting text from /tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image7.png: cannot identify image file '/tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image7.png'
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide18_image6.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-01-21 Bridge Program Workshop_slide14_image3.png - 4 words - SKIPPED (less than 5 words)
# Processed RC Transition From Ped to Adult Email - Peds_page1_image1.png - 2209 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide19_image1.png - 14 words - INCLUDED
# Processed 2025-02-APS OS RIN AD_slide4_image3.png - 2 words - SKIPPED (less than 5 words)
# Processed PSIT RINVOQ-UC9-RIN AD Patient Engagement System_slide2_image3.png - 2 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide10_image7.png - 152 words - INCLUDED
# Error extracting text from /tmp/Bridge Workshop Deck_page3_image5.png: cannot identify image file '/tmp/Bridge Workshop Deck_page3_image5.png'
# Processed Bridge Workshop Deck_page3_image5.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide19_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed Examples of Complete App Push Notifications and Pop-ups_slide6_image2.png - 83 words - INCLUDED
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image2.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image2.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed Screenshot 2025-04-15 170036.png - 130 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide19_image3.png - 394 words - INCLUDED
# Error extracting text from /tmp/Bridge Workshop Deck_page3_image6.png: cannot identify image file '/tmp/Bridge Workshop Deck_page3_image6.png'
# Processed Bridge Workshop Deck_page3_image6.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image3.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image3.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image3.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image4.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image4.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image4.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image8.png: cannot identify image file '/tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image8.png'
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image8.png - 0 words - SKIPPED (less than 5 words)
# Processed Examples of Complete App Push Notifications and Pop-ups_slide6_image3.png - 88 words - INCLUDED
# Error extracting text from /tmp/Bridge Workshop Deck_page3_image7.png: cannot identify image file '/tmp/Bridge Workshop Deck_page3_image7.png'
# Processed Bridge Workshop Deck_page3_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide20_image2.png - 76 words - INCLUDED
# Processed 2025-02-APS OS RIN AD_slide7_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-APS OS RIN AD_slide8_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide10_image8.png - 258 words - INCLUDED
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image5.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image5.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image5.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide21_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-APS OS RIN AD_slide8_image9.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Bridge Workshop Deck_page3_image8.png: cannot identify image file '/tmp/Bridge Workshop Deck_page3_image8.png'
# Processed Bridge Workshop Deck_page3_image8.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-01-21 Bridge Program Workshop_slide14_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-26-Disruption Workshop_slide21_image4.png - 26 words - INCLUDED
# Processed PSIT RINVOQ-UC9-RIN AD Patient Engagement System_slide3_image12.png - 3 words - SKIPPED (less than 5 words)
# Processed Examples of Complete App Push Notifications and Pop-ups_slide7_image2.png - 81 words - INCLUDED
# Processed 2025-02-26-Disruption Workshop_slide22_image4.png - 54 words - INCLUDED
# Processed 2025-02-APS OS RIN AD_slide9_image3.png - 9 words - INCLUDED
# Processed 2025-02-APS OS RIN AD_slide10_image11.png - 3 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image6.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image6.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image6.png - 0 words - SKIPPED (less than 5 words)
# Processed PSIT RINVOQ-UC9-RIN AD Patient Engagement System_slide3_image24.png - 9 words - INCLUDED
# Processed RC Staying on Track Email (1)_page1_image1.png - 2405 words - INCLUDED
# Processed 2025-02-APS OS RIN AD_slide10_image23.png - 9 words - INCLUDED
# Processed 2025-02-APS OS RIN AD_slide10_image24.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image9.png: cannot identify image file '/tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image9.png'
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image9.png - 0 words - SKIPPED (less than 5 words)
# Processed RC Welcome Email - Peds_page1_image1.png - 2213 words - INCLUDED
# Error extracting text from /tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image10.png: cannot identify image file '/tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image10.png'
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image10.png - 0 words - SKIPPED (less than 5 words)
# Processed Pre Fill PA Summary 1_slide1_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Bridge Workshop Deck_page3_image9.png: cannot identify image file '/tmp/Bridge Workshop Deck_page3_image9.png'
# Processed Bridge Workshop Deck_page3_image9.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-APS OS RIN AD_slide11_image6.png - 9 words - INCLUDED
# Processed 2025-02-APS OS RIN AD_slide11_image21.png - 3 words - SKIPPED (less than 5 words)
# Processed RC Insurance Cover Email_page1_image1.png - 2428 words - INCLUDED
# Processed 2025-02-APS OS RIN AD_slide11_image25.png - 1 words - SKIPPED (less than 5 words)
# Processed Examples of Complete App Push Notifications and Pop-ups_slide7_image3.png - 74 words - INCLUDED
# Processed Bridge Workshop Deck_page4_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-APS OS RIN AD_slide11_image26.png - 1 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Bridge Workshop Deck_page4_image2.png: cannot identify image file '/tmp/Bridge Workshop Deck_page4_image2.png'
# Processed Bridge Workshop Deck_page4_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-APS OS RIN AD_slide11_image27.png - 1 words - SKIPPED (less than 5 words)
# Processed Bridge Workshop Deck_page4_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed 2025-02-APS OS RIN AD_slide11_image28.png - 4 words - SKIPPED (less than 5 words)
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image11.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image1.png: cannot identify image file '/tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image1.png'
# Processed Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide10_image9.png - 158 words - INCLUDED
# Error extracting text from /tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image12.png: cannot identify image file '/tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image12.png'
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image12.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed Rinvoq AD PE Tactics Business Design Executive Summaries_slide2_image7.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page1_image1.png: cannot identify image file '/tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page1_image1.png'
# Processed SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image8.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image8.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image8.png - 0 words - SKIPPED (less than 5 words)
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide1_image4.png - 9 words - INCLUDED
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide2_image3.png - 9 words - INCLUDED
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide7_image1.png - 776 words - INCLUDED
# Error extracting text from /tmp/Rinvoq AD PE Tactics Business Design Executive Summaries_slide4_image3.png: Unsupported image format/type
# Processed Rinvoq AD PE Tactics Business Design Executive Summaries_slide4_image3.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image9.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image9.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image9.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page1_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image10.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image10.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image10.png - 0 words - SKIPPED (less than 5 words)
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide7_image2.png - 225 words - INCLUDED
# Error extracting text from /tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page2_image1.png: cannot identify image file '/tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page2_image1.png'
# Processed SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page2_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide10_image10.png - 2 words - SKIPPED (less than 5 words)
# Processed SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image1.png - 57 words - INCLUDED
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide7_image3.png - 225 words - INCLUDED
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image11.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page1_image11.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page1_image11.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide10_image11.png - 130 words - INCLUDED
# Error extracting text from /tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image2.png: cannot identify image file '/tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image2.png'
# Processed SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image3.png - 18 words - INCLUDED
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image1.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image1.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page2_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image13.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rinvoq AD PE Tactics Business Design Executive Summaries_slide4_image4.png: Unsupported image format/type
# Processed Rinvoq AD PE Tactics Business Design Executive Summaries_slide4_image4.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/2024-12-2 Bridge Workshop Agenda and Insights_slide8_image2.png: Unsupported image format/type
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide8_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed Pre Fill PA Summary 1_slide1_image3.png - 2 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page1_image3.png - 3 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image14.png: cannot identify image file '/tmp/Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image14.png'
# Processed Rcomplete_App Leave Behind_Print_Savings Card T&C Update_page1_image14.png - 0 words - SKIPPED (less than 5 words)
# Processed Rinvoq AD PE Tactics Business Design Executive Summaries_slide8_image12.png - 2 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image4.png: cannot identify image file '/tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image4.png'
# Processed SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image4.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image2.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image2.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page2_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image2.png: cannot identify image file '/tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image2.png'
# Processed Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide13_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image5.png - 19 words - INCLUDED
# Processed Rinvoq AD PE Tactics Business Design Executive Summaries_slide8_image17.png - 7 words - INCLUDED
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide16_image3.png - 20 words - INCLUDED
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed Pre Fill PA Summary 1_slide1_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide16_image5.png - 185 words - INCLUDED
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image3.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image3.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page2_image3.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image6.png: cannot identify image file '/tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image6.png'
# Processed SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image6.png - 0 words - SKIPPED (less than 5 words)
# Processed Pre Fill PA Summary 1_slide2_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide17_image4.png - 20 words - INCLUDED
# Error extracting text from /tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image3.png: cannot identify image file '/tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image3.png'
# Processed Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image3.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image7.png: cannot identify image file '/tmp/SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image7.png'
# Processed SMS A&E Wave 2 Rinvoq Lab Rebate Monitoring_page3_image7.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image3.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image3.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image3.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image4.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image4.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page2_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed Rinvoq AD PE Tactics Business Design Executive Summaries_slide9_image12.png - 2 words - SKIPPED (less than 5 words)
# Processed Rinvoq AD PE Tactics Business Design Executive Summaries_slide9_image17.png - 7 words - INCLUDED
# Processed Pre Fill PA Summary 1_slide2_image3.png - 1 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide18_image3.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image5.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image5.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page2_image5.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page1_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed Rinvoq AD PA Denied Discovery_slide2_image7.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rinvoq AD PA Denied Discovery_slide4_image3.png: Unsupported image format/type
# Processed Rinvoq AD PA Denied Discovery_slide4_image3.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rinvoq AD PA Denied Discovery_slide4_image4.png: Unsupported image format/type
# Processed Rinvoq AD PA Denied Discovery_slide4_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed Rinvoq AD PA Denied Discovery_slide8_image12.png - 2 words - SKIPPED (less than 5 words)
# Processed Rinvoq AD PA Denied Discovery_slide8_image17.png - 7 words - INCLUDED
# Processed Rinvoq AD PA Denied Discovery_slide9_image12.png - 2 words - SKIPPED (less than 5 words)
# Processed Rinvoq AD PA Denied Discovery_slide9_image17.png - 7 words - INCLUDED
# Processed RIN AD bridge measurement 2.11.25_slide2_image2.png - 9 words - INCLUDED
# Processed RIN AD bridge measurement 2.11.25_slide3_image2.png - 9 words - INCLUDED
# Processed RIN AD bridge measurement 2.11.25_slide6_image2.png - 23 words - INCLUDED
# Processed RIN AD bridge measurement 2.11.25_slide6_image3.png - 67 words - INCLUDED
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image4.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image4.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image4.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image6.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image6.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page2_image6.png - 0 words - SKIPPED (less than 5 words)
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide9_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page1_image5.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image5.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image5.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page1_image5.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page1_image6.png - 29 words - INCLUDED
# Error extracting text from /tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image4.png: cannot identify image file '/tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image4.png'
# Processed Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image4.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/2024-12-2 Bridge Workshop Agenda and Insights_slide10_image2.png: Unsupported image format/type
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide10_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image1.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image1.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page1_image1.png: cannot identify image file '/tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page1_image1.png'
# Processed RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page1_image2.png: cannot identify image file '/tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page1_image2.png'
# Processed RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page1_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page3_image1.png: cannot identify image file '/tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page3_image1.png'
# Processed RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page3_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed Unbranded Understanding Medicare Brochure Print - Update_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image1.png: cannot identify image file '/tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image1.png'
# Processed RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image7.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image7.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page2_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed Treatment Plan Journey _ SIs with Nodes_slide2_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD bridge measurement 2.11.25_slide7_image4.png - 108 words - INCLUDED
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image2.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image2.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed Treatment Plan Journey _ SIs with Nodes_slide2_image9.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image2.png: cannot identify image file '/tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image2.png'
# Processed RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image5.png: cannot identify image file '/tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image5.png'
# Processed Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image5.png - 0 words - SKIPPED (less than 5 words)
# Processed Treatment Plan Journey _ SIs with Nodes_slide10_image40.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image6.png: cannot identify image file '/tmp/Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image6.png'
# Processed Rcomplete Dr. Discussion Guide (Telemedicine Options) Print - CD LC_page1_image6.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_slide3_image12.png - 3 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_slide3_image24.png - 9 words - INCLUDED
# Processed RIN AD Patient Engagement System Use Case Overview_slide5_image5.png - 1 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image3.png: cannot identify image file '/tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image3.png'
# Processed RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image3.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image4.png: cannot identify image file '/tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image4.png'
# Processed RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image4.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image8.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image8.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page2_image8.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide18_image5.png - 60 words - INCLUDED
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image9.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image9.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page2_image9.png - 0 words - SKIPPED (less than 5 words)
# Processed Treatment Plan Journey _ SIs with Nodes_slide10_image41.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide18_image6.png - 59 words - INCLUDED
# Processed RIN AD Patient Engagement System Use Case Overview_page2_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide11_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image5.png: cannot identify image file '/tmp/RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image5.png'
# Processed RComplete_Kaiser Rebate Brochure_Print_Savings Card T&C Update (1)_page4_image5.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image3.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image3.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide18_image7.png - 48 words - INCLUDED
# Processed RIN AD Patient Engagement System Use Case Overview_slide5_image7.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image10.png: cannot identify image file '/tmp/RC My RINVOQ Routine Print - CD LC Update_page2_image10.png'
# Processed RC My RINVOQ Routine Print - CD LC Update_page2_image10.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image4.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image4.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image4.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image5.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image5.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image5.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image6.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image6.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image6.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_slide5_image9.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD bridge measurement 2.11.25_slide9_image2.png - 9 words - INCLUDED
# Error extracting text from /tmp/2024-12-2 Bridge Workshop Agenda and Insights_slide11_image3.png: Unsupported image format/type
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide11_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_slide5_image11.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page2_image8.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_slide5_image18.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_slide5_image20.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide18_image8.png - 25 words - INCLUDED
# Processed RIN AD Patient Engagement System Use Case Overview_page2_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page2_image3.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/2024-12-2 Bridge Workshop Agenda and Insights_slide11_image4.png: Unsupported image format/type
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide11_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page2_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed RComplete_Intro to AD Adol Brochure_Print_Savings Card T&C Update (1)_page1_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page3_image1.png - 2 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page3_image2.png - 0 words - SKIPPED (less than 5 words)
# ...
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page3_image13.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide5_image12.png - 3 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide32_image14.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide5_image24.png - 9 words - INCLUDED
# Processed RIN AD Bridge Program Optimization Starter Document_slide6_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide6_image6.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide6_image12.png - 0 words - SKIPPED (less than 5 words)
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide33_image9.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page3_image14.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page3_image14.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page3_image14.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide7_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide7_image9.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide9_image3.png - 88 words - INCLUDED
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image8.png - 0 words - SKIPPED (less than 5 words)
# Processed 2024-12-2 Bridge Workshop Agenda and Insights_slide33_image10.png - 0 words - SKIPPED (less than 5 words)
# Processed RComplete_Intro to AD Adol Brochure_Print_Savings Card T&C Update (1)_page6_image1.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page3_image15.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page3_image15.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page3_image15.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image9.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page3_image16.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page3_image16.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page3_image16.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide25_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed 5_6_FAS CSS IS  Overview_Lunch & Learn_slide27_image1.png - 88 words - INCLUDED
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image10.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image1.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image1.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed RComplete_Intro to AD Adol Brochure_Print_Savings Card T&C Update (1)_page7_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide16_image1.png - 80 words - INCLUDED
# Processed RIN AD Bridge Program Optimization Starter Document_slide17_image33.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide17_image34.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image11.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image3.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image3.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide20_image3.png - 200 words - INCLUDED
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image12.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image4.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image4.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image13.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image5.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image6.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image6.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image6.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image7.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image7.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image7.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RComplete_Intro to AD Adol Brochure_Print_Savings Card T&C Update (1)_page7_image2.png: cannot identify image file '/tmp/RComplete_Intro to AD Adol Brochure_Print_Savings Card T&C Update (1)_page7_image2.png'
# Processed RComplete_Intro to AD Adol Brochure_Print_Savings Card T&C Update (1)_page7_image2.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image8.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image8.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image8.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image9.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image9.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page4_image9.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image14.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/RComplete_Intro to AD Adol Brochure_Print_Savings Card T&C Update (1)_page8_image1.png: cannot identify image file '/tmp/RComplete_Intro to AD Adol Brochure_Print_Savings Card T&C Update (1)_page8_image1.png'
# Processed RComplete_Intro to AD Adol Brochure_Print_Savings Card T&C Update (1)_page8_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image15.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide21_image3.png - 232 words - INCLUDED
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image16.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page5_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page6_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image17.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page7_image1.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page7_image1.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page7_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image18.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image19.png - 0 words - SKIPPED (less than 5 words)
# Error extracting text from /tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page7_image2.png: cannot identify image file '/tmp/Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page7_image2.png'
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page7_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page4_image20.png - 0 words - SKIPPED (less than 5 words)
# Processed Rcomplete_Ambassador Services Brochure_Print_Savings Card T&C Update_page7_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image5.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image6.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image8.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image9.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image10.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Bridge Program Optimization Starter Document_slide22_image1.png - 279 words - INCLUDED
# Processed RIN AD Bridge Program Optimization Starter Document_slide27_image17.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image11.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image12.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image13.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image14.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image15.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image16.png - 2 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image17.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image18.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image19.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image20.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image21.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page5_image22.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image2.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image3.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image4.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image5.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image6.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image7.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image8.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image9.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image10.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image11.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image12.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image13.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image14.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image15.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image16.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image17.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image18.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image19.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page6_image20.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page7_image1.png - 0 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page7_image2.png - 2 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page7_image3.png - 3 words - SKIPPED (less than 5 words)
# Processed RIN AD Patient Engagement System Use Case Overview_page7_image4.png - 3 words - SKIPPED (less than 5 words)
# 94 rows successfully written (2Xwrma5vgV)
# Total images processed: 440
# Images included in dataset: 94
# Images excluded (less than 5 words): 346
# Text extraction completed! Added 94 images to dataset.
